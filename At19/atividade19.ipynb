# %% [markdown]
# ## Importação das bibliotecas

# %%
# !pip install google-cloud-storage
# Out:
# Requirement already satisfied: google-cloud-storage in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (2.3.0)
# Requirement already satisfied: google-resumable-media>=2.3.2 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-cloud-storage) (2.3.2)
# Requirement already satisfied: protobuf in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-cloud-storage) (3.20.1)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-cloud-storage) (2.6.6)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-cloud-storage) (2.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-cloud-storage) (2.7.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-cloud-storage) (2.27.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (1.56.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (5.1.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (0.2.8)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-resumable-media>=2.3.2->google-cloud-storage) (1.3.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2021.10.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage) (0.4.8)

# %%
# !pip install gcsfs
# Out:
# Requirement already satisfied: gcsfs in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (2022.3.0)
# Requirement already satisfied: aiohttp<4 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from gcsfs) (3.8.1)
# Requirement already satisfied: decorator>4.1.2 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from gcsfs) (5.1.1)
# Requirement already satisfied: fsspec==2022.3.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from gcsfs) (2022.3.0)
# Requirement already satisfied: google-auth>=1.2 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from gcsfs) (2.6.6)
# Requirement already satisfied: google-auth-oauthlib in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from gcsfs) (0.5.1)
# Requirement already satisfied: requests in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from gcsfs) (2.27.1)
# Requirement already satisfied: google-cloud-storage in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from gcsfs) (2.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4->gcsfs) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4->gcsfs) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4->gcsfs) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4->gcsfs) (1.3.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4->gcsfs) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4->gcsfs) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4->gcsfs) (1.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-auth>=1.2->gcsfs) (5.1.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-auth>=1.2->gcsfs) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-auth>=1.2->gcsfs) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-auth>=1.2->gcsfs) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib->gcsfs) (1.3.1)
# Requirement already satisfied: google-resumable-media>=2.3.2 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-cloud-storage->gcsfs) (2.3.2)
# Requirement already satisfied: protobuf in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-cloud-storage->gcsfs) (3.20.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-cloud-storage->gcsfs) (2.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-cloud-storage->gcsfs) (2.7.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from requests->gcsfs) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from requests->gcsfs) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from requests->gcsfs) (2021.10.8)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->gcsfs) (1.56.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from google-resumable-media>=2.3.2->google-cloud-storage->gcsfs) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.2.0)

# %%
# !pip install pandera
# Out:
# Requirement already satisfied: pandera in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (0.11.0)
# Requirement already satisfied: pydantic in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from pandera) (1.9.0)
# Requirement already satisfied: wrapt in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from pandera) (1.14.1)
# Requirement already satisfied: typing-inspect>=0.6.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from pandera) (0.7.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from pandera) (21.3)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from pandera) (1.22.3)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from pandera) (1.4.2)
# Requirement already satisfied: pyarrow in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from pandera) (8.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from packaging>=20.0->pandera) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.2.0->pandera) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.2.0->pandera) (2022.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from typing-inspect>=0.6.0->pandera) (4.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from typing-inspect>=0.6.0->pandera) (0.4.3)
# Requirement already satisfied: six>=1.5 in c:\users\mecha\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.2.0->pandera) (1.16.0)

# %%
import pandas as pd
import numpy as np
import pandera as pa
import os
from google.cloud import storage

# %% [markdown]
# ## Conectores

# %%
#CONFIGURAÇÃO DA CHAVE DE SEGURANÇA
serviceAccount = 'C://Cursos//Soulcode//At19//weighty-archive-349117-48db0581d7b3.json'

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = serviceAccount

# %%
#CÓDIGO QUE ACESSA A BUCKET CRIADA E FAZ O DOWNLOAD DOS ARQUIVOS VIA PANDAS
client = storage.Client()

#CRIAR UMA VARIÁVEL CHAMADA BUCKET QUE VAI RECEBER O NOME DA BUCKET DO CLOUD STORAGE
bucket = client.get_bucket('16052022')

#USAR O MÉTODO BLOB PARA RETORNAR O NOME DO ARQUIVO (JSON, CSV, PARQUET)
bucket.blob('Acessos_Banda_Larga_Fixa_2021.csv')

#CRIA UMA VARIÁVEL PATH PARA COLOCAR O CAMINHO DO CSV
#path = 'gs://datasets_pyspark/arquivo_geral.csv'
path = 'gs://16052022/Acessos_Banda_Larga_Fixa_2021.csv'

# %%
df_pandas = pd.read_csv(path, sep=';')

# %%
df_pandas
# Out:
#           Ano  Mês   Grupo Econômico  \
# 0        2021   12  TELECOM AMERICAS
# 1        2021   12  TELECOM AMERICAS
# 2        2021   12  TELECOM AMERICAS
# 3        2021   12                OI
# 4        2021   12                OI
# ...       ...  ...               ...
# 5859818  2021    1            OUTROS
# 5859819  2021    1            OUTROS
# 5859820  2021    1            OUTROS
# 5859821  2021    1            OUTROS
# 5859822  2021    1            OUTROS
#
#                                            Empresa            CNPJ  \
# 0                                            CLARO  40432544000147
# 1                                            CLARO  40432544000147
# 2                                            CLARO  40432544000147
# 3                                               OI  76535764000143
# 4                                               OI   5423963000111
# ...                                            ...             ...
# 5859818  C. S. - NET INFORMATICA E TECNOLOGIA LTDA  10482451000166
# 5859819  C. S. - NET INFORMATICA E TECNOLOGIA LTDA  10482451000166
# 5859820  C. S. - NET INFORMATICA E TECNOLOGIA LTDA  10482451000166
# 5859821  C. S. - NET INFORMATICA E TECNOLOGIA LTDA  10482451000166
# 5859822  C. S. - NET INFORMATICA E TECNOLOGIA LTDA  10482451000166
#
#         Porte da Prestadora  UF      Município  Código IBGE Município  \
# 0              Grande Porte  AL   Campo Grande                2701506
# 1              Grande Porte  PR     Guarapuava                4109401
# 2              Grande Porte  RS     Montenegro                4312401
# 3              Grande Porte  SC  Florianópolis                4205407
# 4              Grande Porte  SP         Taiaçu                3553104
# ...                     ...  ..            ...                    ...
# 5859818       Pequeno Porte  SC   Treze Tílias                4218509
# 5859819       Pequeno Porte  SC   Treze Tílias                4218509
# 5859820       Pequeno Porte  SC   Salto Veloso                4215406
# 5859821       Pequeno Porte  SC   Salto Veloso                4215406
# 5859822       Pequeno Porte  SC   Salto Veloso                4215406
#
#         Faixa de Velocidade Tecnologia Meio de Acesso   Tipo de Pessoa  \
# 0           0Kbps a 512Kbps       VSAT       Satélite  Pessoa Jurídica
# 1           0Kbps a 512Kbps      ADSL1  Cabo Metálico  Pessoa Jurídica
# 2           0Kbps a 512Kbps      ADSL1  Cabo Metálico  Pessoa Jurídica
# 3           12Mbps a 34Mbps        ATM  Cabo Metálico  Pessoa Jurídica
# 4           512kbps a 2Mbps       HDSL  Cabo Metálico  Pessoa Jurídica
# ...                     ...        ...            ...              ...
# 5859818      2Mbps a 12Mbps      WIMAX  Indeterminado    Pessoa Física
# 5859819      2Mbps a 12Mbps      WIMAX  Indeterminado  Pessoa Jurídica
# 5859820      2Mbps a 12Mbps      WIMAX  Indeterminado  Pessoa Jurídica
# 5859821      2Mbps a 12Mbps      WIMAX  Indeterminado  Pessoa Jurídica
# 5859822     512kbps a 2Mbps      WIMAX  Indeterminado  Pessoa Jurídica
#
#          Acessos
# 0              2
# 1              1
# 2              1
# 3              5
# 4              1
# ...          ...
# 5859818       25
# 5859819        4
# 5859820        5
# 5859821        2
# 5859822        2
#
# [5859823 rows x 14 columns]

# %% [markdown]
# ## Leitura dos datasets

# %%
pd.set_option('display.max_columns',25)

# %%
df_pandas.head(5)
# Out:
#     Ano  Mês   Grupo Econômico Empresa            CNPJ Porte da Prestadora  \
# 0  2021   12  TELECOM AMERICAS   CLARO  40432544000147        Grande Porte
# 1  2021   12  TELECOM AMERICAS   CLARO  40432544000147        Grande Porte
#
#    UF     Município  Código IBGE Município Faixa de Velocidade Tecnologia  \
# 0  AL  Campo Grande                2701506     0Kbps a 512Kbps       VSAT
# 1  PR    Guarapuava                4109401     0Kbps a 512Kbps      ADSL1
#
#   Meio de Acesso   Tipo de Pessoa  Acessos
# 0       Satélite  Pessoa Jurídica        2
# 1  Cabo Metálico  Pessoa Jurídica        1

# %%
df_pandas.tail(5)

# %%
#renomeando variaveis
df_pandas.rename(columns={'Ano': 'ano','Mês':'mes', 'Grupo Econômico':'grupo_economico', 'Empresa':'empresa',
                 'CNPJ':'cnpj', 'Porte da Prestadora':'porte_empresa', 'UF':'sigla_uf', 'Município':'municipio',
                 'Código IBGE Município':'id_municipio', 'Faixa de Velocidade':'velocidade', 'Tecnologia':'tecnologia',
                 'Meio de Acesso':'transmissao', 'Acessos':'acessos', 'Tipo de Pessoa': 'pessoa'}, inplace=True)

# %%
df_pandas.head(5)
# Out:
#     ano  mes   grupo_economico empresa            cnpj porte_empresa sigla_uf  \
# 0  2021   12  TELECOM AMERICAS   CLARO  40432544000147  Grande Porte       AL
# 1  2021   12  TELECOM AMERICAS   CLARO  40432544000147  Grande Porte       PR
#
#       municipio  id_municipio       velocidade tecnologia    transmissao  \
# 0  Campo Grande       2701506  0Kbps a 512Kbps       VSAT       Satélite
# 1    Guarapuava       4109401  0Kbps a 512Kbps      ADSL1  Cabo Metálico
#
#             pessoa  acessos
# 0  Pessoa Jurídica        2
# 1  Pessoa Jurídica        1

# %%
df_pandas.tail(5)
# Out:
#           ano  mes grupo_economico                                    empresa  \
# 5859818  2021    1          OUTROS  C. S. - NET INFORMATICA E TECNOLOGIA LTDA
# 5859819  2021    1          OUTROS  C. S. - NET INFORMATICA E TECNOLOGIA LTDA
# 5859820  2021    1          OUTROS  C. S. - NET INFORMATICA E TECNOLOGIA LTDA
# 5859821  2021    1          OUTROS  C. S. - NET INFORMATICA E TECNOLOGIA LTDA
# 5859822  2021    1          OUTROS  C. S. - NET INFORMATICA E TECNOLOGIA LTDA
#
#                    cnpj  porte_empresa sigla_uf     municipio  id_municipio  \
# 5859818  10482451000166  Pequeno Porte       SC  Treze Tílias       4218509
# 5859819  10482451000166  Pequeno Porte       SC  Treze Tílias       4218509
# 5859820  10482451000166  Pequeno Porte       SC  Salto Veloso       4215406
# 5859821  10482451000166  Pequeno Porte       SC  Salto Veloso       4215406
# 5859822  10482451000166  Pequeno Porte       SC  Salto Veloso       4215406
#
#               velocidade tecnologia    transmissao           pessoa  acessos
# 5859818   2Mbps a 12Mbps      WIMAX  Indeterminado    Pessoa Física       25
# 5859819   2Mbps a 12Mbps      WIMAX  Indeterminado  Pessoa Jurídica        4
# 5859820   2Mbps a 12Mbps      WIMAX  Indeterminado  Pessoa Jurídica        5
# 5859821   2Mbps a 12Mbps      WIMAX  Indeterminado  Pessoa Jurídica        2
# 5859822  512kbps a 2Mbps      WIMAX  Indeterminado  Pessoa Jurídica        2

# %%
df_pandas.to_csv('gs://16052022/Acessos_Banda_Larga_Fixa_2021_df.csv')
